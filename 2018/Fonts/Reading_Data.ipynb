# %%
import h5py
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
f = h5py.File('fonts.hdf5', 'r')

# %%
data = f['fonts']

# %%
data.shape
# Out:
# (38, 94, 128, 128)

# %%
plt.figure()
sum_data = np.zeros((data.shape[2],data.shape[3]))
for i in range(38):
    plt.subplot(4,10,i+1)
    plt.imshow(data[i,10,:,:],cmap='gray',interpolation = 'lanczos')
    plt.axis('off')
    sum_data = sum_data+data[i,10,:,:]

# %%
plt.figure()
plt.imshow(sum_data/4,cmap = 'gray')

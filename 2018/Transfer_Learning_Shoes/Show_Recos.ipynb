# %%
import pandas as pd
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
data = pd.read_csv('knn.csv')
del data['Unnamed: 0']
data.set_index('0',inplace=True)

# %%
data.head()
# Out:
#        1      2      3
# 0
# 1  24039   8631  11059
# 2   5386  23164  16674
# 3   3593   5784   3695
# 4     21  21494  25039
# 5   5848  11986  13125

# %%
# Out:
# 5020

# %%
sample = np.random.choice(data.index)

plt.figure(figsize=[10,10])

plt.subplot(2,2,1)
im = mpimg.imread('ZapposShoes/Images/'+str(sample)+'.jpg')
plt.imshow(im)
plt.title('Original - '+ str(sample))
plt.axis('off')

plt.subplot(2,2,2)
im = mpimg.imread('ZapposShoes/Images/'+str(data.loc[sample]['1'])+'.jpg')
plt.imshow(im);
plt.title('Recommendation 1 - '+ str(data.loc[sample]['1']))
plt.axis('off')

plt.subplot(2,2,3)
im = mpimg.imread('ZapposShoes/Images/'+str(data.loc[sample]['2'])+'.jpg')
plt.imshow(im);
plt.title('Recommendation 2 - '+ str(data.loc[sample]['2']))
plt.axis('off')

plt.subplot(2,2,4)
im = mpimg.imread('ZapposShoes/Images/'+str(data.loc[sample]['3'])+'.jpg')
plt.imshow(im);
plt.title('Recommendation 3 - '+ str(data.loc[sample]['3']))
plt.axis('off');
